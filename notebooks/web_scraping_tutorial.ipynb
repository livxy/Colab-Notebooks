# %% [markdown]
# <a href="https://colab.research.google.com/github/livxy/Colab-Notebooks/blob/main/notebooks/web_scraping_tutorial.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Load in the necessary libraries

# %%
import requests # pip install requests
from bs4 import BeautifulSoup as bs # pip install beautifulsoup4

# %% [markdown]
# ## Load our first page

# %%
# Load the webpage content
r = requests.get("https://www.etschfarms.com/corn-maze.html")

# Convert to a beautiful soup object
soup = bs(r.content)

# Print out our html
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="IE=edge,chrome=1" http-equiv="X-UA-Compatible"/>
#   <meta content="" name="description"/>
#   <meta content="" name="keywords"/>
#   <meta content="SKYPE_TOOLBAR_PARSER_COMPATIBLE" name="SKYPE_TOOLBAR"/>
#   <link href="css/styles.css" rel="stylesheet" type="text/css"/>
#   <link href="css/elastislide.css" rel="stylesheet" type="text/css"/>
#   <script src="https://ajax.googleapis.com/ajax/libs/jquery/1.8.0/jquery.min.js">
#   </script>
#   <script src="https://ajax.googleapis.com/ajax/libs/mootools/1.4.5/mootools-yui-compressed.js">
#   </script>
#   <script src="js/selectivizr-min.js">
#   </script>
#   <script src="js/modernizr.custom.93041.js">
#   </script>
#   <script src="js/slides.min.jquery.js" type="text/javascript">
#   </script>
#   <script src="js/jquery.easing.1.3.js" type="text/javascript">
#   </script>
#   <script src="js/jquery.elastislide.js" type="text/javascript">
# ...

# %% [markdown]
# # Start using Beautiful Soup to Scrape

# %% [markdown]
# ### find and find_all

# %%
first_header = soup.find("h2")

headers = soup.find_all("h2")
print(headers)
# Out:
# [<h2 style="font-weight: bold; font-size: 24px;">Open Weekends in September and October from 12noon-6pm</h2>, <h2 style="font-weight: bold; font-size: 24px;">Open Columbus Day from 12noon-6pm</h2>, <h2 style="font-size: 18px;">$14.99 (includes tax) ages 3 and up provides guest with a wristband that allows entry to our major attractions: hayride, corn maze and corn train ride.  NO WRISTBAND, NO ENTRY</h2>, <h2 style="font-size: 18px;">Available for additional fee is pumpkin decorating, bakery items, barn shop and pumpkin patch!</h2>, <h2 style="font-size: 18px;">We recommend PRE-PURCHASING TICKETS to increase guest safety.  Each guest must have a ticket for our major attractions.</h2>, <h2><a class="wx-button" href="https://etschfarms.ticketspice.com/maze-2022" style="background:#397e41;color:white;padding:10px 20px;text-decoration:none;font-weight:bold;" target="_blank">Get Tickets</a></h2>, <h2 style="font-size: 18px;">Please arrive within 15 minutes of your starting time.  Guests w
# ...

# %%
# Pass in a list of elements to look for 
first_header = soup.find(["h1", "h2"])

headers = soup.find_all(["h1", "h2"])
headers
# Out:
# [<h1>Corn Maze</h1>,
#  <h2 style="font-weight: bold; font-size: 24px;">Open Weekends in September and October from 12noon-6pm</h2>,
#  <h2 style="font-weight: bold; font-size: 24px;">Open Columbus Day from 12noon-6pm</h2>,
#  <h2 style="font-size: 18px;">$14.99 (includes tax) ages 3 and up provides guest with a wristband that allows entry to our major attractions: hayride, corn maze and corn train ride.  NO WRISTBAND, NO ENTRY</h2>,
#  <h2 style="font-size: 18px;">Available for additional fee is pumpkin decorating, bakery items, barn shop and pumpkin patch!</h2>,
#  <h2 style="font-size: 18px;">We recommend PRE-PURCHASING TICKETS to increase guest safety.  Each guest must have a ticket for our major attractions.</h2>,
#  <h2><a class="wx-button" href="https://etschfarms.ticketspice.com/maze-2022" style="background:#397e41;color:white;padding:10px 20px;text-decoration:none;font-weight:bold;" target="_blank">Get Tickets</a></h2>,
# ...

# %%
# You can pass in attributes to the find/find_all function
paragraph = soup.find_all("p", attrs={"id": "paragraph-id"})
paragraph
# Out:
# []

# %%
# You can nest find/find_all calls
body = soup.find('body')
div = body.find('div')
header = div.find('h1')
header
# Out:
# <h1>Corn Maze</h1>

# %%
# We can search specific strings in our find/find_all calls
import re

paragraphs = soup.find_all("p", string=re.compile("Some"))
paragraphs

headers = soup.find_all("h2", string=re.compile("(H|h)eader"))
headers
# Out:
# []

# %% [markdown]
# ### select (CSS selector)

# %%
print(soup.body.prettify())
# Out:
# <body>
#  <div class="wrapper">
#   <div class="top-strip">
#   </div>
#   <div class="content-out">
#    <div class="header">
#     <div class="sharing">
#      <div class="follow">
#       <!-- AddThis Follow BEGIN -->
#       <p>
#        Follow Us
#       </p>
#       <div class="addthis_toolbox addthis_32x32_style addthis_default_style">
#        <a addthis:userid="180073375375784" class="addthis_button_facebook_follow">
#        </a>
#       </div>
#       <script src="https://s7.addthis.com/js/250/addthis_widget.js#pubid=xa-5032636b07d8cd57" type="text/javascript">
#       </script>
#       <!-- AddThis Follow END -->
#       <p>
#        Share Us
#       </p>
#      </div>
#      <div class="share">
#       <!-- AddThis Button BEGIN -->
#       <div class="addthis_toolbox addthis_default_style ">
#        <a class="addthis_button_preferred_1">
#        </a>
#        <a class="addthis_button_preferred_2">
#        </a>
#        <a class="addthis_button_preferred_3">
# ...

# %%
content = soup.select("div p")
content
# Out:
# [<p>Follow Us</p>,
#  <p>Share Us</p>,
#  <p>Our 8 Acre corn maze operates weekends in September through October.  Get lost with your friends and family, but remember Corn Central is there to get you out.  Enter through our yearly themed big bale creation and start on your path to fun!</p>,
#  <p>Our crossword puzzle game is hidden throughout the maze for an extra challenge.  Looking for something smaller?  Walk through our smaller corn maze and get the same experience!</p>,
#  <p>Enjoy pumpkin picking, a ride on our corn train or hayride.  Swing by our Bakery Barn for fresh apple cider donuts, pies, hot chocolate and more!  Browse our Barn Shop and sample our selection of jams, mustards, and preserves.  Indulge yourself at Etsch Farms, and create long-lasting family memories.</p>,
# ...

# %%
paragraphs = soup.select("h2 ~ p")
paragraphs
# Out:
# [<p>Our 8 Acre corn maze operates weekends in September through October.  Get lost with your friends and family, but remember Corn Central is there to get you out.  Enter through our yearly themed big bale creation and start on your path to fun!</p>,
#  <p>Our crossword puzzle game is hidden throughout the maze for an extra challenge.  Looking for something smaller?  Walk through our smaller corn maze and get the same experience!</p>,
#  <p>Enjoy pumpkin picking, a ride on our corn train or hayride.  Swing by our Bakery Barn for fresh apple cider donuts, pies, hot chocolate and more!  Browse our Barn Shop and sample our selection of jams, mustards, and preserves.  Indulge yourself at Etsch Farms, and create long-lasting family memories.</p>,
#  <p>We proudly support our community services by offering 10% off to our Military, Fire, EMS and Police. Discount is FOR MAZE ENTRY ONLY. Please show an ID to our cashier to receive discount. Discount is non-transferable.</p>,
#  <p><br/>
# ...

# %%
bold_text = soup.select("p#paragraph-id b")
bold_text
# Out:
# []

# %%
paragraphs = soup.select("body > p")
print(paragraphs)

for paragraph in paragraphs:
  print(paragraph.select("i"))
# Out:
# []

# %%
# Grab by element with specific property
soup.select("[align=middle]")
# Out:
# []

# %% [markdown]
# ## Get different properties of the HTML

# %%
# use .string
header = soup.find("h2")
header.string

# If multiple child elements use get_text
div = soup.find("div")
print(div.prettify())
print(div.get_text())
# Out:
# <div class="wrapper">
#  <div class="top-strip">
#  </div>
#  <div class="content-out">
#   <div class="header">
#    <div class="sharing">
#     <div class="follow">
#      <!-- AddThis Follow BEGIN -->
#      <p>
#       Follow Us
#      </p>
#      <div class="addthis_toolbox addthis_32x32_style addthis_default_style">
#       <a addthis:userid="180073375375784" class="addthis_button_facebook_follow">
#       </a>
#      </div>
#      <script src="https://s7.addthis.com/js/250/addthis_widget.js#pubid=xa-5032636b07d8cd57" type="text/javascript">
#      </script>
#      <!-- AddThis Follow END -->
#      <p>
#       Share Us
#      </p>
#     </div>
#     <div class="share">
#      <!-- AddThis Button BEGIN -->
#      <div class="addthis_toolbox addthis_default_style ">
#       <a class="addthis_button_preferred_1">
#       </a>
#       <a class="addthis_button_preferred_2">
#       </a>
#       <a class="addthis_button_preferred_3">
#       </a>
# ...

# %%
# Get a specific property from an element
import requests
from lxml import html

main_url = "http://www.chapter-living.com/properties/highbury"
re = requests.get(main_url)
root = html.fromstring(re.content)
cities_links = [main_url + link for link in root.xpath('//a/@href')]

for n, i in enumerate(cities_links[:n]):
    print(i, cities_links[n], "\n")
# Out:
# http://www.chapter-living.com/properties/highbury# http://www.chapter-living.com/properties/highbury#
#
# http://www.chapter-living.com/properties/highbury/properties/highbury/ http://www.chapter-living.com/properties/highbury/properties/highbury/
#
# http://www.chapter-living.com/properties/highburyhttps://www.chapterlondon.cn/我们的公寓/highbury/ http://www.chapter-living.com/properties/highburyhttps://www.chapterlondon.cn/我们的公寓/highbury/
#
# http://www.chapter-living.com/properties/highburytel:+442072930000 http://www.chapter-living.com/properties/highburytel:+442072930000
#
# http://www.chapter-living.com/properties/highburyhttps://www.chapter-living.com/dist/assets/img/wechat-qrcode.jpg http://www.chapter-living.com/properties/highburyhttps://www.chapter-living.com/dist/assets/img/wechat-qrcode.jpg
#
# http://www.chapter-living.com/properties/highbury/ http://www.chapter-living.com/properties/highbury/
#
# ...

# %% [markdown]
# ## Code navigation

# %%
# Path Syntax
print(soup.body.prettify())
# Out:
# <body>
#  <div class="wrapper">
#   <div class="top-strip">
#   </div>
#   <div class="content-out">
#    <div class="header">
#     <div class="sharing">
#      <div class="follow">
#       <!-- AddThis Follow BEGIN -->
#       <p>
#        Follow Us
#       </p>
#       <div class="addthis_toolbox addthis_32x32_style addthis_default_style">
#        <a addthis:userid="180073375375784" class="addthis_button_facebook_follow">
#        </a>
#       </div>
#       <script src="https://s7.addthis.com/js/250/addthis_widget.js#pubid=xa-5032636b07d8cd57" type="text/javascript">
#       </script>
#       <!-- AddThis Follow END -->
#       <p>
#        Share Us
#       </p>
#      </div>
#      <div class="share">
#       <!-- AddThis Button BEGIN -->
#       <div class="addthis_toolbox addthis_default_style ">
#        <a class="addthis_button_preferred_1">
#        </a>
#        <a class="addthis_button_preferred_2">
#        </a>
#        <a class="addthis_button_preferred_3">
# ...

# %%
# Know the terms: Parent, Sibling, Child

soup.body.find("div").find_next_siblings()
# Out:
# [<script type="text/javascript">
#  			$('#carousel').elastislide({
#  				imageW 	: 220,
#  				minItems : 4
#  			});
#  </script>, <script>
#    (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#    (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#    m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#    })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#    ga('create', 'UA-102181807-1', 'auto');
#    ga('send', 'pageview');
#
#  </script>]
